# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kego.plotting.frame.frame import Frame, Scaffold
from kego.plotting.frame.config_plot import ConfigPlot
from kego.plotting.frame.scaffold import Grid
import polars as pl
import numpy as np

# %%
type(pl.DataFrame(data={"x": [1, 2, 4]})["x"].to_numpy())

# %%
grid = Grid(2, 3)
config_plot = ConfigPlot(x=None, y=None, c=None, style=None)
grid

# %%
grid.transpose()
grid

# %%
grid[2, 1] = 1
grid

# %%
grid.flatten()

# %%
grid

# %%
sc = Scaffold.from_nx_ny(4, 2)

# %%
sc.set(confif_plot=config_plot)
sc

# %%
[x for x in grid]
