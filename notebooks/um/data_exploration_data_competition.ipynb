# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import pathlib
import os

from mlframework import plotting

# %%
FOLDER_COMPETITION = pathlib.Path("../../data/um/um-game-playing-strength-of-mcts-variants/")
# !ls $FOLDER_COMPETITION
FILEPATH_TRAINING = FOLDER_COMPETITION / "train.csv"

# %%
train_raw = pd.read_csv(FILEPATH_TRAINING)#, nrows=100_000)

# %%
train_raw.head(2)

# %%
train_raw["utility_agent1"].hist()

# %%
train_raw.shape#.drop(columns="utility_agent1")

# %%
def prepare_df(df):
    df = df.copy()
    df = df.drop(columns=df.dtypes[df.dtypes == object].index)
    df = df.reset_index(drop=True)
    df = df.drop(columns=df.columns[df.isna().sum(axis=0) == df.shape[0]])
    df = df.reset_index(drop=True)
    return df

train = prepare_df(train_raw)

y = train[["utility_agent1"]]
X = train.drop(columns=["utility_agent1"])

# %%
X.isna().any().any()

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel
# X, y = load_iris(return_X_y=True)
clf = ExtraTreesRegressor(n_estimators=50, n_jobs=16)
clf = clf.fit(X, y)
clf.feature_importances_  
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X_new.shape

# %%
feature_relevance = pd.Series(index=X.columns, data=clf.feature_importances_)
feature_relevance.sort_values(ascending=False).iloc[:10]

# %%
clf.feature_importances_.shape

# %%
plotting.lines.plot_line(range(len(clf.feature_importances_)), clf.feature_importances_)

# %%
X[:10,:]
