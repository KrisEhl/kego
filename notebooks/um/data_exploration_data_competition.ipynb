# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import pathlib
import os

# %%
FOLDER_COMPETITION = pathlib.Path("../../data/um/um-game-playing-strength-of-mcts-variants/")
# !ls $FOLDER_COMPETITION
FILEPATH_TRAINING = FOLDER_COMPETITION / "train.csv"

# %%
train_raw = pd.read_csv(FILEPATH_TRAINING)

# %%
train_raw.head(2)

# %%
train_raw["agent1"].value_counts()
